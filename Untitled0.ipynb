# %% [markdown]
# <a href="https://colab.research.google.com/github/js566/src/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코랩 테스트

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
myvar = "John"
my_var = "John"
print(myvar)
print(my_var)
# Out:
# John
# John

# %%
x,y,z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome
